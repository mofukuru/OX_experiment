# %%
from src.agent import RandomPolicy, CNNAgent, CQCAgent, QCNNAgent
from src.env import Env
import torch

rate_per_NN = []
randagent = RandomPolicy()

n_qubit = 5
cqc_agent = CQCAgent(network="CQCNN_estimator_ZE", num_of_qubit=n_qubit)

print(randagent)
print(cqc_agent)
print(type(randagent))
print(type(cqc_agent))
# Out:
# ...
# <class 'src.agent.RandomPolicy'>
# <class 'src.agent.CQCAgent'>

# %%
print(type(randagent) == RandomPolicy)
# Out:
# True

# %%
print(type(randagent) == CQCAgent)
# Out:
# False

# %%
print(type(cqc_agent) == RandomPolicy)
# Out:
# False

# %%
print(type(cqc_agent) == CQCAgent)
# Out:
# True

# %%
print(type(randagent) != RandomPolicy)
# Out:
# False

# %%
import torch
for _ in range(100):
    print(torch.normal(mean=0, std=1, size=(1,1)))
# Out:
# tensor([[0.2152]])
# tensor([[-1.1008]])
# tensor([[-0.9825]])
# tensor([[-0.7207]])
# tensor([[-0.3000]])
# tensor([[1.3142]])
# tensor([[0.1458]])
# tensor([[-0.0903]])
# tensor([[-1.2444]])
# tensor([[-0.1612]])
# tensor([[1.1014]])
# tensor([[1.4549]])
# tensor([[0.0829]])
# tensor([[-0.6992]])
# tensor([[-0.3915]])
# tensor([[-0.8263]])
# tensor([[0.2299]])
# tensor([[-1.3519]])
# tensor([[1.6030]])
# tensor([[-0.5334]])
# tensor([[0.2603]])
# tensor([[-0.1385]])
# tensor([[0.9120]])
# tensor([[0.2416]])
# tensor([[0.5891]])
# tensor([[-1.4076]])
# tensor([[1.4770]])
# tensor([[-0.9236]])
# tensor([[0.7397]])
# tensor([[0.4905]])
# tensor([[0.3136]])
# tensor([[1.6170]])
# tensor([[0.3988]])
# tensor([[1.2808]])
# tensor([[-0.6945]])
# tensor([[-2.7998]])
# tensor([[-0.8840]])
# tensor([[-1.0731]])
# tensor([[0.8060]])
# tensor([[0.3102]])
# tensor([[1.2493]])
# tensor([[0.2217]])
# tensor([[0.2963]])
# tensor([[-1.1860]])
# tensor([[-1.3228]])
# tensor([[-0.5374]])
# ...

# %%
from src.components import QNNComponent
n_qubit = 3
qc, feature_map_parameters, ansatz_parameters = QNNComponent(n_qubit).HE(feature_map_reps=1, ansatz_reps=1)
display(qc.decompose().draw(output="mpl"))

# %%
from src.components import QNNComponent
n_qubit = 3
qc, feature_map_parameters, ansatz_parameters = QNNComponent(n_qubit).HE(feature_map_reps=1, ansatz_reps=2)
display(qc.decompose().draw(output="mpl"))

# %%
from src.components import QNNComponent
n_qubit = 3
qc, feature_map_parameters, ansatz_parameters = QNNComponent(n_qubit).HE(feature_map_reps=2, ansatz_reps=1)
display(qc.decompose().draw(output="mpl"))

# %%
from src.components import QNNComponent
n_qubit = 5
qc, feature_map_parameters, ansatz_parameters = QNNComponent(n_qubit).HE(feature_map_reps=1, ansatz_reps=5)
display(qc.decompose().draw(output="mpl"))

# %%
from src.components import QCNNComponent, QNNComponent

# %%
circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=18,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14, 16],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15, 17],
).make_qcnn_circuit(embedding_type="ZFeatureMap")

# %%
# circuit.decompose().draw(output="mpl", style="clifford", fold=-1)
circuit.decompose().draw(output="mpl", style="clifford")

# %%
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
print(f"depth: {circuit.decompose().depth()}")
# Out:
# num featuremap params: 18
# num ansatz params: 81
# depth: 21

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 18
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=18,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14, 16],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15, 17],
).make_qcnn_circuit(embedding_type="ZFeatureMap")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 18
# num ansatz params: 81
# OrderedDict([('cx', 72), ('ry', 54), ('rz', 36), ('h', 18), ('p', 18)])
# depth: 17

# %% [markdown]
# ## ここからカウントはじまる

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15],
).make_qcnn_circuit(embedding_type="ZFeatureMap")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 72
# OrderedDict([('cx', 64), ('ry', 48), ('rz', 32), ('h', 16), ('p', 16)])
# depth: 17

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15],
).make_qcnn_circuit(embedding_type="ZZFeatureMap")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 72
# OrderedDict([('cx', 304), ('p', 136), ('ry', 48), ('rz', 32), ('h', 16)])
# depth: 104

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15],
).make_qcnn_circuit(embedding_type="HEE")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 72
# OrderedDict([('cx', 79), ('ry', 48), ('rz', 32), ('rx', 16)])
# depth: 31

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6, 8, 10, 12, 14],
    sinks=[1, 3, 5, 7, 9, 11, 13, 15],
).make_qcnn_circuit(embedding_type="TPE")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 72
# OrderedDict([('cx', 64), ('ry', 48), ('rz', 32), ('rx', 16)])
# depth: 16

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6],
    sinks=[1, 3, 5, 7],
).make_qcnn_circuit(embedding_type="ZFeatureMap")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 36
# OrderedDict([('cx', 32), ('ry', 24), ('rz', 16), ('h', 8), ('p', 8)])
# depth: 17

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6],
    sinks=[1, 3, 5, 7],
).make_qcnn_circuit(embedding_type="ZZFeatureMap")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 36
# OrderedDict([('cx', 88), ('p', 36), ('ry', 24), ('rz', 16), ('h', 8)])
# depth: 56

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6],
    sinks=[1, 3, 5, 7],
).make_qcnn_circuit(embedding_type="HEE")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 36
# OrderedDict([('cx', 39), ('ry', 24), ('rz', 16), ('rx', 8)])
# depth: 23

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QCNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QCNNComponent(
    n_qubits=n_qubits,
    param_prefix="qcnn",
    sources=[0, 2, 4, 6],
    sinks=[1, 3, 5, 7],
).make_qcnn_circuit(embedding_type="TPE")

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 36
# OrderedDict([('cx', 32), ('ry', 24), ('rz', 16), ('rx', 8)])
# depth: 16

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 32
# OrderedDict([('ry', 32), ('h', 16), ('p', 16), ('cx', 15)])
# depth: 19

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 32
# OrderedDict([('cx', 255), ('p', 136), ('ry', 32), ('h', 16)])
# depth: 106

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count)
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 32
# OrderedDict([('ry', 32), ('cx', 30), ('rx', 16)])
# depth: 33

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 32
# 15
# depth: 18

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 64
# 15
# depth: 21

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 64
# 255
# depth: 108

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 64
# 30
# depth: 35

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 16
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 16
# num ansatz params: 64
# 15
# depth: 20

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 18
# 8
# depth: 12

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 18
# 80
# depth: 57

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 18
# 16
# depth: 19

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 18
# 8
# depth: 11

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 36
# 8
# depth: 14

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 36
# 80
# depth: 59

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 36
# 16
# depth: 21

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 9
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 9
# num ansatz params: 36
# 8
# depth: 13

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 16
# 7
# depth: 11

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 16
# 63
# depth: 50

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 16
# 14
# depth: 17

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="RealAmplitudes"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 16
# 7
# depth: 10

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 32
# 7
# depth: 13

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="ZZFeatureMap", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 32
# 63
# depth: 52

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="HEE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 32
# 14
# depth: 19

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator
from src.components import QNNComponent

n_qubits = 8
backend = AerSimulator(
    method="statevector", device="GPU", cuStateVec_enable=True
)

circuit, featuremap, ansatz = QNNComponent(n_qubits=n_qubits).make_circuit(
    embedding_type="TPE", ansatz_type="EfficientSU2"
)

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

display(isa_circuit.draw(output="mpl"))
print(f"num featuremap params: {len(featuremap)}")
print(f"num ansatz params: {len(ansatz)}")
gate_count = isa_circuit.count_ops()
print(gate_count["cx"])
print(f"depth: {isa_circuit.depth()}")
# Out:
# num featuremap params: 8
# num ansatz params: 32
# 7
# depth: 12

# %%
from src.network import CNN_QCNN_CNN
from torchsummary import summary

embedding_type = "ZFeatureMap"
board_size = 3
n_qubits = 8
device = "cuda"

NN = CNN_QCNN_CNN(
    embedding_type=embedding_type,
    board_size=board_size,
    n_qubits=n_qubits,
)

summary(NN.to(device), input_size=(1, board_size**2))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                 [-1, 1, 8]              80
#             Linear-2                 [-1, 1, 8]              80
#     TorchConnector-3                 [-1, 1, 4]              36
#             Linear-4                 [-1, 1, 9]              45
#             Linear-5                 [-1, 1, 9]              45
#               Tanh-6                 [-1, 1, 9]               0
# ...
# Total params: 286
# Trainable params: 286
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------

# %%
from src.network import CNN_QNN_CNN_sampler
from torchsummary import summary

embedding_type = "ZFeatureMap"
ansatz_type = "RealAmplitudes"
feature_map_reps = 1
ansatz_reps = 1
board_size = 3
n_qubits = 8
device = "cuda"

NN = CNN_QNN_CNN_sampler(
    embedding_type=embedding_type,
    ansatz_type=ansatz_type,
    board_size=board_size,
    n_qubits=n_qubits,
    feature_map_reps=feature_map_reps,
    ansatz_reps=ansatz_reps,
)

summary(NN.to(device), input_size=(1, board_size**2))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                 [-1, 1, 8]              80
#     TorchConnector-2               [-1, 1, 256]              16
#             Linear-3                 [-1, 1, 9]           2,313
#               Tanh-4                 [-1, 1, 9]               0
# ...
# Total params: 2,409
# Trainable params: 2,409
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
